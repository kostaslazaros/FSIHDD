# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kostaslazaros/FSIHDD/blob/master/cross_val_experiment_result_visualization.ipynb)

# %%
from scipy.stats import mannwhitneyu
from statannotations.Annotator import Annotator
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
def create_boxplot(data, x="Data", y="Accuracy", pairs=[("Original", "FSC")], alg_name="K Nearest Neighbors", pdf_name="knn_acc.pdf"):
    x = x
    y = y
    pairs=pairs
    a4_dims = (5, 7)
    fig, ax = plt.subplots(figsize=a4_dims)
    ax.set_title(alg_name, fontsize=19)
    sns.boxplot(data=data, x=x, y=y , width=0.25)
    annotator = Annotator(ax, pairs, data=data, x=x, y=y)
    annotator.configure(test='Mann-Whitney', text_format='star', loc='inside')
    annotator.apply_and_annotate()
    plt.savefig(pdf_name, dpi=150, bbox_inches='tight')

# %%
rfc_scores = pd.read_csv('alg_scores/random_forest_scores.csv')

# %%
rfc_scores
# Out:
#      Accuracy  F1 score      Data
# 0    0.697411  0.789177  Original
# 1    0.844660  0.904192  Original
# 2    0.846278  0.905095  Original
# 3    0.800971  0.876382  Original
# 4    0.794498  0.876098  Original
# ..        ...       ...       ...
# 295  0.822006  0.889558     ANOVA
# 296  0.867314  0.915114     ANOVA
# 297  0.891586  0.930426     ANOVA
# 298  0.889789  0.929019     ANOVA
# 299  0.878444  0.919614     ANOVA
#
# [300 rows x 3 columns]

# %%
lrc_scores = pd.read_csv('alg_scores/logistic_regression_scores.csv')

# %%
knn_scores = pd.read_csv('alg_scores/k_nearest_neighbors_scores.csv')

# %%
svm_scores = pd.read_csv('alg_scores/support_vector_machine_scores.csv')

# %% [markdown]
# ### Results for Random Forest

# %% [markdown]
# #### For the original dataset (18958 features/genes)

# %%
create_boxplot(rfc_scores, 'Data', 'Accuracy', [("Original", "FSC"), ("ANOVA", "FSC")], 'Random Forest', 'rfc_acc.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:1.655e-22 U_stat=1.005e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:2.414e-06 U_stat=6.930e+03

# %%
create_boxplot(rfc_scores, 'Data', 'F1 score', [("Original", "FSC"), ("ANOVA", "FSC")], 'Random Forest', 'rfc_f1.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:4.344e-22 U_stat=1.045e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:3.012e-07 U_stat=7.097e+03

# %%
create_boxplot(lrc_scores, 'Data', 'Accuracy', [("Original", "FSC"), ("ANOVA", "FSC")], 'Logistic Regression', 'lrc_acc.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:3.920e-01 U_stat=4.650e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:1.221e-22 U_stat=9.000e+03

# %%
create_boxplot(lrc_scores, 'Data', 'F1 score', [("Original", "FSC"), ("ANOVA", "FSC")], 'Logistic Regression', 'lrc_f1.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:5.415e-01 U_stat=4.750e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:1.086e-17 U_stat=8.500e+03

# %%
create_boxplot(knn_scores, 'Data', 'Accuracy', [("Original", "FSC"), ("ANOVA", "FSC")], 'K Nearest Neighbors', 'knn_acc.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:9.052e-17 U_stat=1.600e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:8.919e-11 U_stat=7.650e+03

# %%
create_boxplot(knn_scores, 'Data', 'F1 score', [("Original", "FSC"), ("ANOVA", "FSC")], 'K Nearest Neighbors', 'knn_f1.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:4.984e-15 U_stat=1.800e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:1.000e-06 U_stat=7.000e+03

# %%
create_boxplot(svm_scores, 'Data', 'Accuracy', [("Original", "FSC"), ("ANOVA", "FSC")], 'Support Vector Machine', 'svm_acc.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:1.422e-01 U_stat=5.600e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:1.027e-17 U_stat=8.500e+03

# %%
create_boxplot(svm_scores, 'Data', 'F1 score', [("Original", "FSC"), ("ANOVA", "FSC")], 'Support Vector Machine', 'svm_f1.pdf')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Original vs. FSC: Mann-Whitney-Wilcoxon test two-sided, P_val:1.425e-01 U_stat=5.600e+03
# FSC vs. ANOVA: Mann-Whitney-Wilcoxon test two-sided, P_val:9.052e-17 U_stat=8.400e+03
